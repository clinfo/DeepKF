# %%
import pandas as pd

# %%
pd.read_table("log.txt")
# Out:
#     [LOG]  epoch  train cost  valid. cost  alpha  beta  gamma  \
# 0   [LOG]      0   11.677500    12.076700    0.1   0.1      0
# 1   [LOG]      1    3.874900     3.985000    0.1   0.1      0
# 2   [LOG]      2    2.594370     2.589090    0.1   0.1      0
# 3   [LOG]      3    2.416050     2.398140    0.1   0.1      0
# 4   [LOG]      4    2.382060     2.367450    0.1   0.1      0
# ..    ...    ...         ...          ...    ...   ...    ...
# 95  [LOG]     95    1.493330     1.477450    0.1   0.1      0
# 96  [LOG]     96    1.417290     1.407870    0.1   0.1      0
# 97  [LOG]     97    1.146970     1.136670    0.1   0.1      0
# 98  [LOG]     98    0.883574     0.892099    0.1   0.1      0
# 99  [LOG]     99    0.705910     0.709410    0.1   0.1      0
#
#     train error(recons_mse)  valid. error(recons_mse)  train cost(recons)  \
# 0                  0.055700                  0.059124            6.939237
# ...

# %%
log=pd.read_table("log.txt")

# %%
print(log["train cost"])
# Out:
# 0     11.677500
# 1      3.874900
# 2      2.594370
# 3      2.416050
# 4      2.382060
#         ...
# 95     1.493330
# 96     1.417290
# 97     1.146970
# 98     0.883574
# 99     0.705910
# Name: train cost, Length: 100, dtype: float64

# %%
p=log.plot("epoch","train cost(recons)")

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(log["epoch"],log["valid. cost"])
plt.show()
