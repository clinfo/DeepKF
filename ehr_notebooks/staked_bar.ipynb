# %%
#from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LogisticRegression

#標準化用
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

import pandas as pd

#import scipy.stats as sp
import pickle
import numpy
import joblib

import matplotlib.cm as cm
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

from sklearn.metrics.cluster import adjusted_rand_score
from scipy.cluster.hierarchy import fcluster
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

# %%
c_c_death_PT_ID = numpy.load('all_cancer/data/c_c_death_PT_ID.npy')
c_c_death_PT_ID = list(c_c_death_PT_ID)
c_c_PT_ID = pd.read_csv('all_cancer/data/point_inj/all/list_all_cancer_p_or_inj_without_age.csv')
c_c_PT_ID = list(c_c_PT_ID['0'])

#steps読み込み
import numpy
all_data_steps = numpy.load('all_cancer/data/point_inj/all/all_cancer_p_or_inj_without_age_steps.npy')
all_data_steps[0]

print("#number of patients:",len(c_c_PT_ID))
print("#number of death patients:",len(c_c_death_PT_ID))

#潜在状態空間の点（ヒートマップのデータ）を読み込み
#["z_params"][0]=>平均：データ数　x タイムステップ x 状態空間次元
#result_all_cancer_p_or_inj_without_age_dim8_lr005_FFF
obj_dim2=joblib.load("pt_id/model/point_inj/result_all_cancer_p_or_inj_without_age_dim8_lr005_FFF/test.jbl")
x_dim2 = obj_dim2["z_params"][0]

# %%
#特定の抗がん剤投与眼患者の抽出
anti_agent_PT_ID = pd.read_csv('pt_id_clean_parsed_df_prescrip_4291009.csv')
#ニボルマブ
n_anti_agent_PT_ID = pd.read_csv('all_cancer/data/point_inj/all/list_nivo_without_age.csv')
#trastuzumabハーセプチン
t_anti_agent_PT_ID = pd.read_csv('pt_id_clean_df_inj_opz_4291406.csv')
#シスプラチン
c_anti_agent_PT_ID = pd.read_csv('pt_id_clean_df_inj_opz_4291401.csv')
#ビカルタミド・カソデックス
b_anti_agent_PT_ID = pd.read_csv('pt_id_clean_parsed_df_prescrip_4291009.csv')
#imatinibグリベック
i_anti_agent_PT_ID = pd.read_csv('pt_id_clean_parsed_df_prescrip_4291011.csv')
#Osimertinibタグリッソ
o_anti_agent_PT_ID = pd.read_csv('pt_id_clean_parsed_df_prescrip_4291045.csv')
#afatinibジオトリフpt_id_clean_parsed_df_prescrip_4291030
a_anti_agent_PT_ID = pd.read_csv('pt_id_clean_parsed_df_prescrip_4291030.csv')
#erlotinib
e_anti_agent_PT_ID = pd.read_csv('pt_id_clean_parsed_df_prescrip_4291016.csv')

n_anti_agent_PT_ID = list(n_anti_agent_PT_ID['0'])
n_anti_agent_PT_ID_list = []
for i in range(len(n_anti_agent_PT_ID)):
    anti_agent_PT_ID_one = str(n_anti_agent_PT_ID[i])
    n_anti_agent_PT_ID_list.append(anti_agent_PT_ID_one)
n_anti_agent_PT_ID = n_anti_agent_PT_ID_list
n_anti_agent_PT_ID

t_anti_agent_PT_ID = list(t_anti_agent_PT_ID['0'])
t_anti_agent_PT_ID_list = []
for i in range(len(t_anti_agent_PT_ID)):
    anti_agent_PT_ID_one = str(t_anti_agent_PT_ID[i])
    t_anti_agent_PT_ID_list.append(anti_agent_PT_ID_one)
t_anti_agent_PT_ID = t_anti_agent_PT_ID_list
t_anti_agent_PT_ID

c_anti_agent_PT_ID = list(c_anti_agent_PT_ID['0'])
c_anti_agent_PT_ID_list = []
for i in range(len(c_anti_agent_PT_ID)):
    anti_agent_PT_ID_one = str(c_anti_agent_PT_ID[i])
    c_anti_agent_PT_ID_list.append(anti_agent_PT_ID_one)
c_anti_agent_PT_ID = c_anti_agent_PT_ID_list
c_anti_agent_PT_ID

b_anti_agent_PT_ID = list(b_anti_agent_PT_ID['0'])
b_anti_agent_PT_ID_list = []
for i in range(len(b_anti_agent_PT_ID)):
    anti_agent_PT_ID_one = str(b_anti_agent_PT_ID[i])
    b_anti_agent_PT_ID_list.append(anti_agent_PT_ID_one)
b_anti_agent_PT_ID = b_anti_agent_PT_ID_list
b_anti_agent_PT_ID

i_anti_agent_PT_ID = list(i_anti_agent_PT_ID['0'])
i_anti_agent_PT_ID_list = []
for i in range(len(i_anti_agent_PT_ID)):
    anti_agent_PT_ID_one = str(i_anti_agent_PT_ID[i])
    i_anti_agent_PT_ID_list.append(anti_agent_PT_ID_one)
i_anti_agent_PT_ID = i_anti_agent_PT_ID_list
i_anti_agent_PT_ID

o_anti_agent_PT_ID = list(o_anti_agent_PT_ID['0'])
o_anti_agent_PT_ID_list = []
for i in range(len(o_anti_agent_PT_ID)):
    anti_agent_PT_ID_one = str(o_anti_agent_PT_ID[i])
    o_anti_agent_PT_ID_list.append(anti_agent_PT_ID_one)
o_anti_agent_PT_ID = o_anti_agent_PT_ID_list
o_anti_agent_PT_ID

a_anti_agent_PT_ID = list(a_anti_agent_PT_ID['0'])
a_anti_agent_PT_ID_list = []
for i in range(len(a_anti_agent_PT_ID)):
    anti_agent_PT_ID_one = str(a_anti_agent_PT_ID[i])
    a_anti_agent_PT_ID_list.append(anti_agent_PT_ID_one)
a_anti_agent_PT_ID = a_anti_agent_PT_ID_list
a_anti_agent_PT_ID

e_anti_agent_PT_ID = list(e_anti_agent_PT_ID['0'])
e_anti_agent_PT_ID_list = []
for i in range(len(e_anti_agent_PT_ID)):
    anti_agent_PT_ID_one = str(e_anti_agent_PT_ID[i])
    e_anti_agent_PT_ID_list.append(anti_agent_PT_ID_one)
e_anti_agent_PT_ID = e_anti_agent_PT_ID_list
e_anti_agent_PT_ID

# %%
c_c_PT_ID
c_c_PT_ID_lis = []
for i in range(len(c_c_PT_ID)):
    c_c_PT_ID_one = str(c_c_PT_ID[i])
    c_c_PT_ID_lis.append(c_c_PT_ID_one)
c_c_PT_ID = c_c_PT_ID_lis

# %%
len(c_c_PT_ID)

# %% [markdown]
# # deruta_T　dataの取得

# %% [markdown]
# all_data_df_for_deruta_T_merged = pd.read_csv('all_cancer/data/all_data_df_for_deruta_T_merged.csv')
# all_data_df_for_deruta_T_merged

# %%
all_data_df_for_deruta_T_merged = pd.read_csv('all_cancer/data/point_inj/all/df_all_cancer_p_or_inj_without_age_merge_for_deruta_t.csv')
all_data_df_for_deruta_T_merged

# %%
k = 238
n = all_data_df_for_deruta_T_merged.shape[0]
dfs = [all_data_df_for_deruta_T_merged.loc[i:i+k-1, :] for i in range(0, n, k)]
#for df_i in dfs:
    #display(df_i)  
deruta_T = all_data_df_for_deruta_T_merged['Δt']

all_data_steps_new = []
for i in range(len(all_data_steps)):
    all_data_steps_one = all_data_steps[i]
    if all_data_steps_one > 238:
        all_data_steps_new.append(238)
    else:
        all_data_steps_new.append(all_data_steps_one)
all_data_steps = all_data_steps_new

# %% [markdown]
# # random sampling + pt_no

# %%
#random sampling 10こに適当に分割
import random
import numpy as np

#random seed固定（仮）
random.seed(0)
#シャッフル
c_c_PT_ID_random = list(random.sample(c_c_PT_ID, len(c_c_PT_ID)))
#10分割->1
pt_sample_splited = list(np.array_split(c_c_PT_ID_random, 1)) 
pt_sample_splited[0]
#並び替え＋ to list
sample_splited = []
for i in range(1):
    pt_sample_splited_one = list(pt_sample_splited[i])
    pt_sample_splited_one = sorted(pt_sample_splited_one)
    print(len(pt_sample_splited_one))
    sample_splited.append(pt_sample_splited_one)
sample_splited[0]

# %%
r_c_c_PT_ID = sample_splited[0]

r_c_c_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in r_c_c_PT_ID:
        r_c_c_pt_no.append(i)

# %%
n_anti_agent_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in n_anti_agent_PT_ID_list:
        n_anti_agent_pt_no.append(i)
n_anti_agent_pt_no

t_anti_agent_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in t_anti_agent_PT_ID_list:
        t_anti_agent_pt_no.append(i)
t_anti_agent_pt_no

c_anti_agent_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in c_anti_agent_PT_ID_list:
        c_anti_agent_pt_no.append(i)
c_anti_agent_pt_no

b_anti_agent_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in b_anti_agent_PT_ID_list:
        b_anti_agent_pt_no.append(i)
b_anti_agent_pt_no

i_anti_agent_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in i_anti_agent_PT_ID_list:
        i_anti_agent_pt_no.append(i)
i_anti_agent_pt_no

o_anti_agent_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in o_anti_agent_PT_ID_list:
        o_anti_agent_pt_no.append(i)
o_anti_agent_pt_no

a_anti_agent_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in a_anti_agent_PT_ID_list:
        a_anti_agent_pt_no.append(i)
a_anti_agent_pt_no

e_anti_agent_pt_no = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in e_anti_agent_PT_ID_list:
        e_anti_agent_pt_no.append(i)
e_anti_agent_pt_no

# %%
#PT_ID表記
#death_ptとnot_death_ptを分ける
death_pt = []
not_death_pt = []
for i in range(len(c_c_PT_ID)):
    one_c_c_PT_ID = c_c_PT_ID[i]
    if one_c_c_PT_ID in c_c_death_PT_ID:
        death_pt.append(i)
    else:
        not_death_pt.append(i)
        
death_pt = set(r_c_c_pt_no) & set(death_pt)
not_death_pt = set(r_c_c_pt_no) & set(not_death_pt)

print(len(death_pt))
print(len(not_death_pt))

# %%
list_r_c_c_pt_no = list(r_c_c_pt_no)
r_c_c_pt_no_1 = []
death_pt_no_1 = []
not_death_pt_no_1 = []
for i in range(len(list_r_c_c_pt_no)):
    r_c_c_pt_no_one = r_c_c_pt_no[i]
    r_c_c_pt_no_1.append(i)
    if r_c_c_pt_no_one in death_pt:
        death_pt_no_1.append(i)
    else:
        not_death_pt_no_1.append(i)
print(len(r_c_c_pt_no_1))
print(len(death_pt_no_1))
print(len(not_death_pt_no_1))
death_pt_no_1

# %% [markdown]
# # dataset

# %%
# %%time
#make datasets of all cancer patients
df_x_dim2 = []
for i in range(len(c_c_PT_ID)):
    x_dim2_one = dfs[i]
    x_dim2_one = pd.DataFrame(x_dim2_one)
    all_data_steps_one = all_data_steps_new[i]
    x_dim2_one = x_dim2_one.head(all_data_steps_one)
    #最初の3steps捨てる~!!!(改良)
    x_dim2_one = x_dim2_one.tail(-3)
    
    x_dim2_one['pt_no'] = i
    # i -> death_pt[i]
    df_x_dim2.append(x_dim2_one)
#print(df_x_dim2[0])

concat_df_x_dim2 = pd.concat(df_x_dim2)
concat_df_x_dim2 = concat_df_x_dim2.reset_index(drop=True)

list_pt_no = concat_df_x_dim2['pt_no']
df_pt_no = pd.DataFrame(list_pt_no)
concat_df_x_dim2 = concat_df_x_dim2.drop(['pt_no'], axis = 1)
df_pt_no

# %%
# %%time
#make datasets of all cancer patients
df_x_dim2 = []
for i in range(len(c_c_PT_ID)):
    x_dim2_one = x_dim2[i]
    x_dim2_one = pd.DataFrame(x_dim2_one)
    all_data_steps_one = all_data_steps[i]
    x_dim2_one = x_dim2_one.head(all_data_steps_one)
    #最初の3steps捨てる~!!!(改良)
    x_dim2_one = x_dim2_one.tail(-3)
    
    x_dim2_one['pt_no'] = i
    # i -> death_pt[i]
    df_x_dim2.append(x_dim2_one)
#print(df_x_dim2[0])

concat_df_x_dim2 = pd.concat(df_x_dim2)
concat_df_x_dim2 = concat_df_x_dim2.reset_index(drop=True)

list_pt_no = concat_df_x_dim2['pt_no']
df_pt_no = pd.DataFrame(list_pt_no)
concat_df_x_dim2 = concat_df_x_dim2.drop(['pt_no'], axis = 1)
df_pt_no

# %% [markdown]
# # deruta_Tの計算

# %%
# %%time
#ΔTをlast pointからの日数になるように計算
time_span = []

for i in r_c_c_pt_no:
    dfs_one = dfs[i]
    dfs_one = list(dfs_one['Δt'])
    dfs_steps_one = all_data_steps[i]
    dfs_one = dfs_one[0 : dfs_steps_one]
    dfs_one.reverse()
    
    time_sum = []
    for j in range(dfs_steps_one):
        dfs_one_sum = sum(dfs_one[0 : j])
        dfs_one_sum = dfs_one_sum *-1
        time_sum.append(dfs_one_sum)
    time_sum.reverse()
    
    #最初の3steps捨てる~!!!(改良)
    time_sum = time_sum[3 : ]
    time_sum = time_sum 
    time_span.append(time_sum)
    
time_span[0]

# %%
X_transformed = pd.read_csv('for_py_all_cancer_p_or_i_notage_analysis_for_UMAP_X_transformed.csv', index_col=0)
X_transformed

# %%
#解体作業 
X_transformed_dim2 = pd.concat([X_transformed, df_pt_no], axis = 1, join = 'inner') 
X_transformed_dim2 
transformed_dim2 = []
for x in  r_c_c_pt_no: 
#for x in not_death_pt:
    X_transformed_dim2_i = X_transformed_dim2[X_transformed_dim2['pt_no'] == x] 
    X_transformed_dim2_i = X_transformed_dim2_i.drop(['pt_no'], axis = 1) 
    transformed_dim2.append(X_transformed_dim2_i)
transformed_dim2[0]

# %%
X_transformed_dim2_for_kmeans = X_transformed_dim2.drop(['pt_no'], axis = 1)

# %%
#culuster = 3
X_transformed
dim8_lr005_cluster_labels3 = np.load('all_p_or_i_before_dim8_lr005_cluster_labels3.npy')

dim8_lr005_cluster_labels3 = list(dim8_lr005_cluster_labels3)
X_transformed['label'] = dim8_lr005_cluster_labels3

# %%
X_transformed
#解体作業 
X_transformed_dim2 = pd.concat([X_transformed, df_pt_no], axis = 1, join = 'inner') 
X_transformed_dim2 
transformed_dim2 = []
for x in  r_c_c_pt_no: 
#for x in not_death_pt:
    X_transformed_dim2_i = X_transformed_dim2[X_transformed_dim2['pt_no'] == x] 
    X_transformed_dim2_i = X_transformed_dim2_i.drop(['pt_no'], axis = 1) 
    transformed_dim2.append(X_transformed_dim2_i)
transformed_dim2[1]

# %%
# %%time
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))

for p, x_dim2 in enumerate(transformed_dim2):
    x = x_dim2['0']
    y = x_dim2['1']
    labels = x_dim2['label']
    colors = []

    for label in labels:
        if label == 2:
            #青安定
            colors.append((91/255, 155/255, 213/255))
        elif label == 1:
            colors.append((236/255, 125/255, 238/255))
            #ピンク危険
        elif label == 0:
            #gray普通
            colors.append((180/255, 180/255, 180/255))
    
    plt.scatter(x, y, color=colors, marker='o', s=5)

plt.xticks([])  # x軸の目盛りを非表示
plt.yticks([])  # y軸の目盛りを非表示
plt.grid(True)
plt.show()
plt.savefig('latent_state_clustering.eps')

# %% [markdown]
# # 統計量比較のためのデータセット作成

# %%
#解体して結合する
dfs[0]
df_for_comparing = []
for i in range(len(r_c_c_pt_no)):
    dfs_one = dfs[i]
    time_steps_one = all_data_steps_new[i]
    dfs_one = dfs_one.head(time_steps_one)
    #最初の3stepsは初期学習不良のため捨てる
    dfs_one = dfs_one.tail(-3)
    df_for_comparing.append(dfs_one)
df_for_comparing_merge = pd.concat(df_for_comparing)
df_for_comparing_merge['pt_no'] = list(df_pt_no['pt_no'])
df_for_comparing_merge['label'] = dim8_lr005_cluster_labels3
#len(df_for_comparing_merge) : 1660734rows

df_for_comparing_merge


#ニボルマブ投与がん患者さん対象
#nivo_c_c_pt_no
df_for_comparing_merge
n_df_for_comparing = []
for i in n_anti_agent_pt_no:
    df_for_comparing_merge_one = df_for_comparing_merge[df_for_comparing_merge.pt_no == i]
    n_df_for_comparing.append(df_for_comparing_merge_one)
n_df_for_comparing_merge = pd.concat(n_df_for_comparing)
n_df_for_comparing_merge

##trastuzumabハーセプチン
t_df_for_comparing = []
for i in t_anti_agent_pt_no:
    df_for_comparing_merge_one = df_for_comparing_merge[df_for_comparing_merge.pt_no == i]
    t_df_for_comparing.append(df_for_comparing_merge_one)
t_df_for_comparing_merge = pd.concat(t_df_for_comparing)
t_df_for_comparing_merge

###シスプラチン
c_df_for_comparing = []
for i in c_anti_agent_pt_no:
    df_for_comparing_merge_one = df_for_comparing_merge[df_for_comparing_merge.pt_no == i]
    c_df_for_comparing.append(df_for_comparing_merge_one)
c_df_for_comparing_merge = pd.concat(c_df_for_comparing)
c_df_for_comparing_merge

b_df_for_comparing = []
for i in b_anti_agent_pt_no:
    df_for_comparing_merge_one = df_for_comparing_merge[df_for_comparing_merge.pt_no == i]
    b_df_for_comparing.append(df_for_comparing_merge_one)
b_df_for_comparing_merge = pd.concat(b_df_for_comparing)

i_df_for_comparing = []
for i in i_anti_agent_pt_no:
    df_for_comparing_merge_one = df_for_comparing_merge[df_for_comparing_merge.pt_no == i]
    i_df_for_comparing.append(df_for_comparing_merge_one)
i_df_for_comparing_merge = pd.concat(i_df_for_comparing)

o_df_for_comparing = []
for i in o_anti_agent_pt_no:
    df_for_comparing_merge_one = df_for_comparing_merge[df_for_comparing_merge.pt_no == i]
    o_df_for_comparing.append(df_for_comparing_merge_one)
o_df_for_comparing_merge = pd.concat(o_df_for_comparing)

a_df_for_comparing = []
for i in a_anti_agent_pt_no:
    df_for_comparing_merge_one = df_for_comparing_merge[df_for_comparing_merge.pt_no == i]
    a_df_for_comparing.append(df_for_comparing_merge_one)
a_df_for_comparing_merge = pd.concat(a_df_for_comparing)

e_df_for_comparing = []
for i in e_anti_agent_pt_no:
    df_for_comparing_merge_one = df_for_comparing_merge[df_for_comparing_merge.pt_no == i]
    e_df_for_comparing.append(df_for_comparing_merge_one)
e_df_for_comparing_merge = pd.concat(e_df_for_comparing)

# %%
items= [
    "ALB",
    "CRP",
    "MCHC",
    "RBC",
    "HCT",
    "血清血糖",
    "γ-GTP",
    "HGB",
    "CK",
    "LDH",
    "CRE (eGFR)",
    "WBC",
    "AST/GOT",
    "TP",
    "T-CHO",
    "ALT/GPT",
    "PLT",
    "Ca",
    "BUN",
    "ALP",
    "Na",
    "MCH",
    "MCV",
    "網赤血球[‰]",
    "Cl",
    "Ch-E",
    "UA",
    "AMY",
    "Lymphocyte",
    "K",
    "Monocyte",
    "D.D-dimer",
    "TG",
    "Eosinophil",
    "Neutrophil",
    "PT(act)",
    "T-Bil",
    "APTT",
    "PT(INR)",
    "Segmented",
    "FIB",
    "LAP",
    "血漿血糖",
    "CEA",
    "IP",
    "Mg",
    "抱合型D-Bil",
    "HbA1c(JDS)",
    "Band",
    "CYFRA"
]

# %%
#クラスター1の場合
n_df_for_comparing_merge_1 = n_df_for_comparing_merge[n_df_for_comparing_merge.label == 1]
t_df_for_comparing_merge_1 = t_df_for_comparing_merge[t_df_for_comparing_merge.label == 1]
c_df_for_comparing_merge_1 = c_df_for_comparing_merge[c_df_for_comparing_merge.label == 1]
b_df_for_comparing_merge_1 = b_df_for_comparing_merge[b_df_for_comparing_merge.label == 1]
i_df_for_comparing_merge_1 = i_df_for_comparing_merge[i_df_for_comparing_merge.label == 1]
o_df_for_comparing_merge_1 = o_df_for_comparing_merge[o_df_for_comparing_merge.label == 1]
a_df_for_comparing_merge_1 = a_df_for_comparing_merge[a_df_for_comparing_merge.label == 1]
e_df_for_comparing_merge_1 = e_df_for_comparing_merge[e_df_for_comparing_merge.label == 1]

all_df_for_comparing_merge_1 = df_for_comparing_merge[df_for_comparing_merge.label == 1]

# %%
#クラスター2の場合
n_df_for_comparing_merge_2 = n_df_for_comparing_merge[n_df_for_comparing_merge.label == 0]
t_df_for_comparing_merge_2 = t_df_for_comparing_merge[t_df_for_comparing_merge.label == 0]
c_df_for_comparing_merge_2 = c_df_for_comparing_merge[c_df_for_comparing_merge.label == 0]
b_df_for_comparing_merge_2 = b_df_for_comparing_merge[b_df_for_comparing_merge.label == 0]
i_df_for_comparing_merge_2 = i_df_for_comparing_merge[i_df_for_comparing_merge.label == 0]
o_df_for_comparing_merge_2 = o_df_for_comparing_merge[o_df_for_comparing_merge.label == 0]
a_df_for_comparing_merge_2 = a_df_for_comparing_merge[a_df_for_comparing_merge.label == 0]
e_df_for_comparing_merge_2 = e_df_for_comparing_merge[e_df_for_comparing_merge.label == 0]

all_df_for_comparing_merge_2 = df_for_comparing_merge[df_for_comparing_merge.label == 0]

# %%
#クラスター3の場合
n_df_for_comparing_merge_3 = n_df_for_comparing_merge[n_df_for_comparing_merge.label == 2]
t_df_for_comparing_merge_3 = t_df_for_comparing_merge[t_df_for_comparing_merge.label == 2]
c_df_for_comparing_merge_3 = c_df_for_comparing_merge[c_df_for_comparing_merge.label == 2]
b_df_for_comparing_merge_3 = b_df_for_comparing_merge[b_df_for_comparing_merge.label == 2]
i_df_for_comparing_merge_3 = i_df_for_comparing_merge[i_df_for_comparing_merge.label == 2]
o_df_for_comparing_merge_3 = o_df_for_comparing_merge[o_df_for_comparing_merge.label == 2]
a_df_for_comparing_merge_3 = a_df_for_comparing_merge[a_df_for_comparing_merge.label == 2]
e_df_for_comparing_merge_3 = e_df_for_comparing_merge[e_df_for_comparing_merge.label == 2]

all_df_for_comparing_merge_3 = df_for_comparing_merge[df_for_comparing_merge.label == 2]

# %%
n_df_for_comparing_merge_1 = n_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
t_df_for_comparing_merge_1= t_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
c_df_for_comparing_merge_1 = c_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
b_df_for_comparing_merge_1 = b_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
i_df_for_comparing_merge_1 = i_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
o_df_for_comparing_merge_1 = o_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
a_df_for_comparing_merge_1 = a_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
e_df_for_comparing_merge_1 = e_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
all_df_for_comparing_merge_1 = all_df_for_comparing_merge_1[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]

all_df_for_comparing_merge_1

# %%
n_df_for_comparing_merge_2 = n_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
t_df_for_comparing_merge_2= t_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
c_df_for_comparing_merge_2 = c_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
b_df_for_comparing_merge_2 = b_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
i_df_for_comparing_merge_2 = i_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
o_df_for_comparing_merge_2 = o_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
a_df_for_comparing_merge_2 = a_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
e_df_for_comparing_merge_2 = e_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
all_df_for_comparing_merge_2 = all_df_for_comparing_merge_2[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]

all_df_for_comparing_merge_2

# %%
n_df_for_comparing_merge_3 = n_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
t_df_for_comparing_merge_3= t_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
c_df_for_comparing_merge_3 = c_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
b_df_for_comparing_merge_3 = b_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
i_df_for_comparing_merge_3 = i_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
o_df_for_comparing_merge_3 = o_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
a_df_for_comparing_merge_3 = a_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
e_df_for_comparing_merge_3 = e_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]
all_df_for_comparing_merge_3 = all_df_for_comparing_merge_3[['0206020', '0206040', '0462000', '0206030', '0202000', '0201000']]

all_df_for_comparing_merge_3

# %%
list_need_name = ['Segmented', 'Lymphocyte', 'γ-GTP', 'Band', 'HGB', 'HCT']

n_value_counts_by_column = n_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
n_column_sum = n_value_counts_by_column.sum()
n_value_counts_by_column = n_value_counts_by_column.div(n_column_sum, axis=1)
n_value_counts_by_column.columns = list_need_name
n_value_counts_by_column.index = [-1, 0, 1]
n_value_counts_by_column

t_value_counts_by_column = t_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
t_column_sum = t_value_counts_by_column.sum()
t_value_counts_by_column = t_value_counts_by_column.div(t_column_sum, axis=1)
t_value_counts_by_column.columns = list_need_name
t_value_counts_by_column.index = [-1, 0, 1]
t_value_counts_by_column

c_value_counts_by_column = c_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
c_column_sum = c_value_counts_by_column.sum()
c_value_counts_by_column = c_value_counts_by_column.div(c_column_sum, axis=1)
c_value_counts_by_column.columns = list_need_name
c_value_counts_by_column.index = [-1, 0, 1]
c_value_counts_by_column

b_value_counts_by_column = b_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
b_column_sum = b_value_counts_by_column.sum()
b_value_counts_by_column = b_value_counts_by_column.div(b_column_sum, axis=1)
b_value_counts_by_column.columns = list_need_name
b_value_counts_by_column.index = [-1, 0, 1]
b_value_counts_by_column

i_value_counts_by_column = i_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
i_column_sum = i_value_counts_by_column.sum()
i_value_counts_by_column = i_value_counts_by_column.div(i_column_sum, axis=1)
i_value_counts_by_column.columns = list_need_name
i_value_counts_by_column.index = [-1, 0, 1]
i_value_counts_by_column

o_value_counts_by_column = o_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
o_column_sum = o_value_counts_by_column.sum()
o_value_counts_by_column = o_value_counts_by_column.div(o_column_sum, axis=1)
o_value_counts_by_column.columns = list_need_name
o_value_counts_by_column.index = [-1, 0, 1]
o_value_counts_by_column

a_value_counts_by_column = a_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
a_column_sum = a_value_counts_by_column.sum()
a_value_counts_by_column = a_value_counts_by_column.div(a_column_sum, axis=1)
a_value_counts_by_column.columns = list_need_name
a_value_counts_by_column.index = [-1, 0, 1]
a_value_counts_by_column

e_value_counts_by_column = e_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
e_column_sum = e_value_counts_by_column.sum()
e_value_counts_by_column = e_value_counts_by_column.div(e_column_sum, axis=1)
e_value_counts_by_column.columns = list_need_name
e_value_counts_by_column.index = [-1, 0, 1]
e_value_counts_by_column

all_value_counts_by_column = all_df_for_comparing_merge_1.apply(lambda col: col.value_counts())
all_column_sum = all_value_counts_by_column.sum()
all_value_counts_by_column = all_value_counts_by_column.div(all_column_sum, axis=1)
all_value_counts_by_column.columns = list_need_name
all_value_counts_by_column.index = [-1, 0, 1]
all_value_counts_by_column

# %%
list_need_name_2 = ['Segmented', 'Lymphocyte', 'γ-GTP', 'Band', 'HGB', 'HCT']

n_value_counts_by_column_2 = n_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
n_column_sum_2 = n_value_counts_by_column_2.sum()
n_value_counts_by_column_2 = n_value_counts_by_column_2.div(n_column_sum_2, axis=1)
n_value_counts_by_column_2.columns = list_need_name_2
n_value_counts_by_column_2.index = [-1, 0, 1]
n_value_counts_by_column_2

t_value_counts_by_column_2 = t_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
t_column_sum_2 = t_value_counts_by_column_2.sum()
t_value_counts_by_column_2 = t_value_counts_by_column_2.div(t_column_sum_2, axis=1)
t_value_counts_by_column_2.columns = list_need_name_2
t_value_counts_by_column_2.index = [-1, 0, 1]
t_value_counts_by_column_2

c_value_counts_by_column_2 = c_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
c_column_sum_2 = c_value_counts_by_column_2.sum()
c_value_counts_by_column_2 = c_value_counts_by_column_2.div(c_column_sum_2, axis=1)
c_value_counts_by_column_2.columns = list_need_name_2
c_value_counts_by_column_2.index = [-1, 0, 1]
c_value_counts_by_column_2

b_value_counts_by_column_2 = b_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
b_column_sum_2 = b_value_counts_by_column_2.sum()
b_value_counts_by_column_2 = b_value_counts_by_column_2.div(b_column_sum_2, axis=1)
b_value_counts_by_column_2.columns = list_need_name_2
b_value_counts_by_column_2.index = [-1, 0, 1]
b_value_counts_by_column_2

i_value_counts_by_column_2 = i_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
i_column_sum_2 = i_value_counts_by_column_2.sum()
i_value_counts_by_column_2 = i_value_counts_by_column_2.div(i_column_sum_2, axis=1)
i_value_counts_by_column_2.columns = list_need_name_2
i_value_counts_by_column_2.index = [-1, 0, 1]
i_value_counts_by_column_2

o_value_counts_by_column_2 = o_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
o_column_sum_2 = o_value_counts_by_column_2.sum()
o_value_counts_by_column_2 = o_value_counts_by_column_2.div(o_column_sum_2, axis=1)
o_value_counts_by_column_2.columns = list_need_name_2
o_value_counts_by_column_2.index = [-1, 0, 1]
o_value_counts_by_column_2

a_value_counts_by_column_2 = a_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
a_column_sum_2 = a_value_counts_by_column_2.sum()
a_value_counts_by_column_2 = a_value_counts_by_column_2.div(a_column_sum_2, axis=1)
a_value_counts_by_column_2.columns = list_need_name_2
a_value_counts_by_column_2.index = [-1, 0, 1]
a_value_counts_by_column_2

e_value_counts_by_column_2 = e_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
e_column_sum_2 = e_value_counts_by_column_2.sum()
e_value_counts_by_column_2 = e_value_counts_by_column_2.div(e_column_sum_2, axis=1)
e_value_counts_by_column_2.columns = list_need_name_2
e_value_counts_by_column_2.index = [-1, 0, 1]
e_value_counts_by_column_2

all_value_counts_by_column_2 = all_df_for_comparing_merge_2.apply(lambda col: col.value_counts())
all_column_sum_2 = all_value_counts_by_column_2.sum()
all_value_counts_by_column_2 = all_value_counts_by_column_2.div(all_column_sum_2, axis=1)
all_value_counts_by_column_2.columns = list_need_name_2
all_value_counts_by_column_2.index = [-1, 0, 1]
all_value_counts_by_column_2

# %%
list_need_name_3 = ['Segmented', 'Lymphocyte', 'γ-GTP', 'Band', 'HGB', 'HCT']

n_value_counts_by_column_3 = n_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
n_column_sum_3 = n_value_counts_by_column_3.sum()
n_value_counts_by_column_3 = n_value_counts_by_column_3.div(n_column_sum_3, axis=1)
n_value_counts_by_column_3.columns = list_need_name_3
n_value_counts_by_column_3.index = [-1, 0, 1]
n_value_counts_by_column_3

t_value_counts_by_column_3 = t_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
t_column_sum_3 = t_value_counts_by_column_3.sum()
t_value_counts_by_column_3 = t_value_counts_by_column_3.div(t_column_sum_3, axis=1)
t_value_counts_by_column_3.columns = list_need_name_3
t_value_counts_by_column_3.index = [-1, 0, 1]
t_value_counts_by_column_3

c_value_counts_by_column_3 = c_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
c_column_sum_3 = c_value_counts_by_column_3.sum()
c_value_counts_by_column_3 = c_value_counts_by_column_3.div(c_column_sum_3, axis=1)
c_value_counts_by_column_3.columns = list_need_name_3
c_value_counts_by_column_3.index = [-1, 0, 1]
c_value_counts_by_column_3

b_value_counts_by_column_3 = b_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
b_column_sum_3 = b_value_counts_by_column_3.sum()
b_value_counts_by_column_3 = b_value_counts_by_column_3.div(b_column_sum_3, axis=1)
b_value_counts_by_column_3.columns = list_need_name_3
b_value_counts_by_column_3.index = [-1, 0, 1]
b_value_counts_by_column_3

i_value_counts_by_column_3 = i_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
i_column_sum_3 = i_value_counts_by_column_3.sum()
i_value_counts_by_column_3 = i_value_counts_by_column_3.div(i_column_sum_3, axis=1)
i_value_counts_by_column_3.columns = list_need_name_3
i_value_counts_by_column_3.index = [-1, 0, 1]
i_value_counts_by_column_3

o_value_counts_by_column_3 = o_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
o_column_sum_3 = o_value_counts_by_column_3.sum()
o_value_counts_by_column_3 = o_value_counts_by_column_3.div(o_column_sum_3, axis=1)
o_value_counts_by_column_3.columns = list_need_name_3
o_value_counts_by_column_3.index = [-1, 0, 1]
o_value_counts_by_column_3

a_value_counts_by_column_3 = a_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
a_column_sum_3 = a_value_counts_by_column_3.sum()
a_value_counts_by_column_3 = a_value_counts_by_column_3.div(a_column_sum_3, axis=1)
a_value_counts_by_column_3.columns = list_need_name_3
a_value_counts_by_column_3.index = [-1, 0, 1]
a_value_counts_by_column_3

e_value_counts_by_column_3 = e_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
e_column_sum_3 = e_value_counts_by_column_3.sum()
e_value_counts_by_column_3 = e_value_counts_by_column_3.div(e_column_sum_3, axis=1)
e_value_counts_by_column_3.columns = list_need_name_3
e_value_counts_by_column_3.index = [-1, 0, 1]
e_value_counts_by_column_3

all_value_counts_by_column_3 = all_df_for_comparing_merge_3.apply(lambda col: col.value_counts())
all_column_sum_3 = all_value_counts_by_column_3.sum()
all_value_counts_by_column_3 = all_value_counts_by_column_3.div(all_column_sum_3, axis=1)
all_value_counts_by_column_3.columns = list_need_name_3
all_value_counts_by_column_3.index = [-1, 0, 1]
all_value_counts_by_column_3

# %%
n_value_counts_by_column['Segmented']

# %%
segmented_df = pd.DataFrame(n_value_counts_by_column['Segmented'])
segmented_df.rename(columns={'Segmented': 'Nivolumab'}, inplace=True)
segmented_df['Trastuzumab'] = t_value_counts_by_column['Segmented']
segmented_df['Cisplatin'] = c_value_counts_by_column['Segmented']
segmented_df['Bicalutamide'] = b_value_counts_by_column['Segmented']
segmented_df['Imatinib'] = i_value_counts_by_column['Segmented']
segmented_df['Osimertinib'] = o_value_counts_by_column['Segmented']
segmented_df['Afatinib'] = a_value_counts_by_column['Segmented']
segmented_df['Erlotinib'] = e_value_counts_by_column['Segmented']
segmented_df['All'] = all_value_counts_by_column['Segmented']


lymphocyte_df = pd.DataFrame(n_value_counts_by_column['Lymphocyte'])
lymphocyte_df.rename(columns={'Lymphocyte': 'Nivolumab'}, inplace=True)
lymphocyte_df['Trastuzumab'] = t_value_counts_by_column['Lymphocyte']
lymphocyte_df['Cisplatin'] = c_value_counts_by_column['Lymphocyte']
lymphocyte_df['Bicalutamide'] = b_value_counts_by_column['Lymphocyte']
lymphocyte_df['Imatinib'] = i_value_counts_by_column['Lymphocyte']
lymphocyte_df['Osimertinib'] = o_value_counts_by_column['Lymphocyte']
lymphocyte_df['Afatinib'] = a_value_counts_by_column['Lymphocyte']
lymphocyte_df['Erlotinib'] = e_value_counts_by_column['Lymphocyte']
lymphocyte_df['All'] = all_value_counts_by_column['Lymphocyte']


gtp_df = pd.DataFrame(n_value_counts_by_column['γ-GTP'])
gtp_df.rename(columns={'γ-GTP': 'Nivolumab'}, inplace=True)
gtp_df['Trastuzumab'] = t_value_counts_by_column['γ-GTP']
gtp_df['Cisplatin'] = c_value_counts_by_column['γ-GTP']
gtp_df['Bicalutamide'] = b_value_counts_by_column['γ-GTP']
gtp_df['Imatinib'] = i_value_counts_by_column['γ-GTP']
gtp_df['Osimertinib'] = o_value_counts_by_column['γ-GTP']
gtp_df['Afatinib'] = a_value_counts_by_column['γ-GTP']
gtp_df['Erlotinib'] = e_value_counts_by_column['γ-GTP']
gtp_df['All'] = all_value_counts_by_column['γ-GTP']


band_df = pd.DataFrame(n_value_counts_by_column['Band'])
band_df.rename(columns={'Band': 'Nivolumab'}, inplace=True)
band_df['Trastuzumab'] = t_value_counts_by_column['Band']
band_df['Cisplatin'] = c_value_counts_by_column['Band']
band_df['Bicalutamide'] = b_value_counts_by_column['Band']
band_df['Imatinib'] = i_value_counts_by_column['Band']
band_df['Osimertinib'] = o_value_counts_by_column['Band']
band_df['Afatinib'] = a_value_counts_by_column['Band']
band_df['Erlotinib'] = e_value_counts_by_column['Band']
band_df['All'] = all_value_counts_by_column['Band']


hgb_df = pd.DataFrame(n_value_counts_by_column['HGB'])
hgb_df.rename(columns={'HGB': 'Nivolumab'}, inplace=True)
hgb_df['Trastuzumab'] = t_value_counts_by_column['HGB']
hgb_df['Cisplatin'] = c_value_counts_by_column['HGB']
hgb_df['Bicalutamide'] = b_value_counts_by_column['HGB']
hgb_df['Imatinib'] = i_value_counts_by_column['HGB']
hgb_df['Osimertinib'] = o_value_counts_by_column['HGB']
hgb_df['Afatinib'] = a_value_counts_by_column['HGB']
hgb_df['Erlotinib'] = e_value_counts_by_column['HGB']
hgb_df['All'] = all_value_counts_by_column['HGB']

hgb_df

# %%
hct_df = pd.DataFrame(n_value_counts_by_column['HCT'])
hct_df.rename(columns={'HCT': 'Nivolumab'}, inplace=True)
hct_df['Trastuzumab'] = t_value_counts_by_column['HCT']
hct_df['Cisplatin'] = c_value_counts_by_column['HCT']
hct_df['Bicalutamide'] = b_value_counts_by_column['HCT']
hct_df['Imatinib'] = i_value_counts_by_column['HCT']
hct_df['Osimertinib'] = o_value_counts_by_column['HCT']
hct_df['Afatinib'] = a_value_counts_by_column['HCT']
hct_df['Erlotinib'] = e_value_counts_by_column['HCT']
hct_df['All'] = all_value_counts_by_column['HCT']
hct_df


hct_df_2 = pd.DataFrame(n_value_counts_by_column_2['HCT'])
hct_df_2.rename(columns={'HCT': 'Nivolumab'}, inplace=True)
hct_df_2['Trastuzumab'] = t_value_counts_by_column_2['HCT']
hct_df_2['Cisplatin'] = c_value_counts_by_column_2['HCT']
hct_df_2['Bicalutamide'] = b_value_counts_by_column_2['HCT']
hct_df_2['Imatinib'] = i_value_counts_by_column_2['HCT']
hct_df_2['Osimertinib'] = o_value_counts_by_column_2['HCT']
hct_df_2['Afatinib'] = a_value_counts_by_column_2['HCT']
hct_df_2['Erlotinib'] = e_value_counts_by_column_2['HCT']
hct_df_2['All'] = all_value_counts_by_column_2['HCT']
hct_df_2

hct_df_3 = pd.DataFrame(n_value_counts_by_column_3['HCT'])
hct_df_3.rename(columns={'HCT': 'Nivolumab'}, inplace=True)
hct_df_3['Trastuzumab'] = t_value_counts_by_column_3['HCT']
hct_df_3['Cisplatin'] = c_value_counts_by_column_3['HCT']
hct_df_3['Bicalutamide'] = b_value_counts_by_column_3['HCT']
hct_df_3['Imatinib'] = i_value_counts_by_column_3['HCT']
hct_df_3['Osimertinib'] = o_value_counts_by_column_3['HCT']
hct_df_3['Afatinib'] = a_value_counts_by_column_3['HCT']
hct_df_3['Erlotinib'] = e_value_counts_by_column_3['HCT']
hct_df_3['All'] = all_value_counts_by_column_3['HCT']
hct_df_3

# %%
segmented_df_2 = pd.DataFrame(n_value_counts_by_column_2['Segmented'])
segmented_df_2.rename(columns={'Segmented': 'Nivolumab'}, inplace=True)
segmented_df_2['Trastuzumab'] = t_value_counts_by_column_2['Segmented']
segmented_df_2['Cisplatin'] = c_value_counts_by_column_2['Segmented']
segmented_df_2['Bicalutamide'] = b_value_counts_by_column_2['Segmented']
segmented_df_2['Imatinib'] = i_value_counts_by_column_2['Segmented']
segmented_df_2['Osimertinib'] = o_value_counts_by_column_2['Segmented']
segmented_df_2['Afatinib'] = a_value_counts_by_column_2['Segmented']
segmented_df_2['Erlotinib'] = e_value_counts_by_column_2['Segmented']
segmented_df_2['All'] = all_value_counts_by_column_2['Segmented']


lymphocyte_df_2 = pd.DataFrame(n_value_counts_by_column_2['Lymphocyte'])
lymphocyte_df_2.rename(columns={'Lymphocyte': 'Nivolumab'}, inplace=True)
lymphocyte_df_2['Trastuzumab'] = t_value_counts_by_column_2['Lymphocyte']
lymphocyte_df_2['Cisplatin'] = c_value_counts_by_column_2['Lymphocyte']
lymphocyte_df_2['Bicalutamide'] = b_value_counts_by_column_2['Lymphocyte']
lymphocyte_df_2['Imatinib'] = i_value_counts_by_column_2['Lymphocyte']
lymphocyte_df_2['Osimertinib'] = o_value_counts_by_column_2['Lymphocyte']
lymphocyte_df_2['Afatinib'] = a_value_counts_by_column_2['Lymphocyte']
lymphocyte_df_2['Erlotinib'] = e_value_counts_by_column_2['Lymphocyte']
lymphocyte_df_2['All'] = all_value_counts_by_column_2['Lymphocyte']


gtp_df_2 = pd.DataFrame(n_value_counts_by_column_2['γ-GTP'])
gtp_df_2.rename(columns={'γ-GTP': 'Nivolumab'}, inplace=True)
gtp_df_2['Trastuzumab'] = t_value_counts_by_column_2['γ-GTP']
gtp_df_2['Cisplatin'] = c_value_counts_by_column_2['γ-GTP']
gtp_df_2['Bicalutamide'] = b_value_counts_by_column_2['γ-GTP']
gtp_df_2['Imatinib'] = i_value_counts_by_column_2['γ-GTP']
gtp_df_2['Osimertinib'] = o_value_counts_by_column_2['γ-GTP']
gtp_df_2['Afatinib'] = a_value_counts_by_column_2['γ-GTP']
gtp_df_2['Erlotinib'] = e_value_counts_by_column_2['γ-GTP']
gtp_df_2['All'] = all_value_counts_by_column_2['γ-GTP']


band_df_2 = pd.DataFrame(n_value_counts_by_column_2['Band'])
band_df_2.rename(columns={'Band': 'Nivolumab'}, inplace=True)
band_df_2['Trastuzumab'] = t_value_counts_by_column_2['Band']
band_df_2['Cisplatin'] = c_value_counts_by_column_2['Band']
band_df_2['Bicalutamide'] = b_value_counts_by_column_2['Band']
band_df_2['Imatinib'] = i_value_counts_by_column_2['Band']
band_df_2['Osimertinib'] = o_value_counts_by_column_2['Band']
band_df_2['Afatinib'] = a_value_counts_by_column_2['Band']
band_df_2['Erlotinib'] = e_value_counts_by_column_2['Band']
band_df_2['All'] = all_value_counts_by_column_2['Band']


hgb_df_2 = pd.DataFrame(n_value_counts_by_column_2['HGB'])
hgb_df_2.rename(columns={'HGB': 'Nivolumab'}, inplace=True)
hgb_df_2['Trastuzumab'] = t_value_counts_by_column_2['HGB']
hgb_df_2['Cisplatin'] = c_value_counts_by_column_2['HGB']
hgb_df_2['Bicalutamide'] = b_value_counts_by_column_2['HGB']
hgb_df_2['Imatinib'] = i_value_counts_by_column_2['HGB']
hgb_df_2['Osimertinib'] = o_value_counts_by_column_2['HGB']
hgb_df_2['Afatinib'] = a_value_counts_by_column_2['HGB']
hgb_df_2['Erlotinib'] = e_value_counts_by_column_2['HGB']
hgb_df_2['All'] = all_value_counts_by_column_2['HGB']

hgb_df_2

# %%
segmented_df_3 = pd.DataFrame(n_value_counts_by_column_3['Segmented'])
segmented_df_3.rename(columns={'Segmented': 'Nivolumab'}, inplace=True)
segmented_df_3['Trastuzumab'] = t_value_counts_by_column_3['Segmented']
segmented_df_3['Cisplatin'] = c_value_counts_by_column_3['Segmented']
segmented_df_3['Bicalutamide'] = b_value_counts_by_column_3['Segmented']
segmented_df_3['Imatinib'] = i_value_counts_by_column_3['Segmented']
segmented_df_3['Osimertinib'] = o_value_counts_by_column_3['Segmented']
segmented_df_3['Afatinib'] = a_value_counts_by_column_3['Segmented']
segmented_df_3['Erlotinib'] = e_value_counts_by_column_3['Segmented']
segmented_df_3['All'] = all_value_counts_by_column_3['Segmented']


lymphocyte_df_3 = pd.DataFrame(n_value_counts_by_column_3['Lymphocyte'])
lymphocyte_df_3.rename(columns={'Lymphocyte': 'Nivolumab'}, inplace=True)
lymphocyte_df_3['Trastuzumab'] = t_value_counts_by_column_3['Lymphocyte']
lymphocyte_df_3['Cisplatin'] = c_value_counts_by_column_3['Lymphocyte']
lymphocyte_df_3['Bicalutamide'] = b_value_counts_by_column_3['Lymphocyte']
lymphocyte_df_3['Imatinib'] = i_value_counts_by_column_3['Lymphocyte']
lymphocyte_df_3['Osimertinib'] = o_value_counts_by_column_3['Lymphocyte']
lymphocyte_df_3['Afatinib'] = a_value_counts_by_column_3['Lymphocyte']
lymphocyte_df_3['Erlotinib'] = e_value_counts_by_column_3['Lymphocyte']
lymphocyte_df_3['All'] = all_value_counts_by_column_3['Lymphocyte']


gtp_df_3 = pd.DataFrame(n_value_counts_by_column_3['γ-GTP'])
gtp_df_3.rename(columns={'γ-GTP': 'Nivolumab'}, inplace=True)
gtp_df_3['Trastuzumab'] = t_value_counts_by_column_3['γ-GTP']
gtp_df_3['Cisplatin'] = c_value_counts_by_column_3['γ-GTP']
gtp_df_3['Bicalutamide'] = b_value_counts_by_column_3['γ-GTP']
gtp_df_3['Imatinib'] = i_value_counts_by_column_3['γ-GTP']
gtp_df_3['Osimertinib'] = o_value_counts_by_column_3['γ-GTP']
gtp_df_3['Afatinib'] = a_value_counts_by_column_3['γ-GTP']
gtp_df_3['Erlotinib'] = e_value_counts_by_column_3['γ-GTP']
gtp_df_3['All'] = all_value_counts_by_column_3['γ-GTP']


band_df_3 = pd.DataFrame(n_value_counts_by_column_3['Band'])
band_df_3.rename(columns={'Band': 'Nivolumab'}, inplace=True)
band_df_3['Trastuzumab'] = t_value_counts_by_column_3['Band']
band_df_3['Cisplatin'] = c_value_counts_by_column_3['Band']
band_df_3['Bicalutamide'] = b_value_counts_by_column_3['Band']
band_df_3['Imatinib'] = i_value_counts_by_column_3['Band']
band_df_3['Osimertinib'] = o_value_counts_by_column_3['Band']
band_df_3['Afatinib'] = a_value_counts_by_column_3['Band']
band_df_3['Erlotinib'] = e_value_counts_by_column_3['Band']
band_df_3['All'] = all_value_counts_by_column_3['Band']


hgb_df_3= pd.DataFrame(n_value_counts_by_column_3['HGB'])
hgb_df_3.rename(columns={'HGB': 'Nivolumab'}, inplace=True)
hgb_df_3['Trastuzumab'] = t_value_counts_by_column_3['HGB']
hgb_df_3['Cisplatin'] = c_value_counts_by_column_3['HGB']
hgb_df_3['Bicalutamide'] = b_value_counts_by_column_3['HGB']
hgb_df_3['Imatinib'] = i_value_counts_by_column_3['HGB']
hgb_df_3['Osimertinib'] = o_value_counts_by_column_3['HGB']
hgb_df_3['Afatinib'] = a_value_counts_by_column_3['HGB']
hgb_df_3['Erlotinib'] = e_value_counts_by_column_3['HGB']
hgb_df_3['All'] = all_value_counts_by_column_3['HGB']

hgb_df_3

# %%
segmented_df = segmented_df.T
segmented_df['clu'] = 'Cluster1'
segmented_df

segmented_df_2 = segmented_df_2.T
segmented_df_2['clu'] = 'Cluster2'
segmented_df_2

segmented_df_3 = segmented_df_3.T
segmented_df_3['clu'] = 'Cluster3'
segmented_df_3

# %%
segmented_df

# %%
segmented_df = pd.concat([segmented_df, segmented_df_2, segmented_df_3])
segmented_df

# %%
a = segmented_df.reset_index()
a.columns # 列 label の取得
a = a.groupby(['index', 'clu']).mean()

# %%
new_index = ['Afatinib clu1', 'Afatinib clu2', 'Afatinib clu3', 'All clu1', 'All clu2', 'All clu3', 'Bicalutamide clu1', 'Bicalutamide clu2', 'Bicalutamide clu3', 'Cisplatin clu1', 'Cisplatin clu2', 'Cisplatin clu3', 'Erlotinib clu1', 'Erlotinib clu2', 'Erlotinib clu3', 'Imatinib clu1', 'Imatinib clu2', 'Imatinib clu3', 'Nivolumab clu1', 'Nivolumab clu2', 'Nivolumab clu3', 'Osimertinib clu1', 'Osimertinib clu2', 'Osimertinib clu3', 'Trastuzumab clu1', 'Trastuzumab clu2', 'Trastuzumab clu3']
new_index = ['Afatinib  Cluster I    ', 'Afatinib  Cluster II   ', 'Afatinib  Cluster III  ', 'All  Cluster I    ', 'All  Cluster II   ', 'All  Cluster III  ', 'Bicalutamide  Cluster I    ', 'Bicalutamide  Cluster II   ', 'Bicalutamide  Cluster III  ', 'Cisplatin  Cluster I    ', 'Cisplatin  Cluster II   ', 'Cisplatin  Cluster III  ', 'Erlotinib  Cluster I    ', 'Erlotinib  Cluster II   ', 'Erlotinib  Cluster III  ', 'Imatinib  Cluster I    ', 'Imatinib  Cluster II   ', 'Imatinib  Cluster III  ', 'Nivolumab  Cluster I    ', 'Nivolumab  Cluster II   ', 'Nivolumab  Cluster III  ', 'Osimertinib  Cluster I    ', 'Osimertinib  Cluster II   ', 'Osimertinib  Cluster III  ', 'Trastuzumab  Cluster I    ', 'Trastuzumab  Cluster II   ', 'Trastuzumab  Cluster III  ']

a_simple = a.set_index(pd.Index(new_index))

# 4〜6行目を最後に移動する
new_order = list(a_simple.index[:3]) + list(a_simple.index[6:]) + list(a_simple.index[3:6])
a_simple_reordered = a_simple.reindex(new_order)

a_simple_reordered

# %% [markdown]
# # Stacked barの作成

# %%
df = a_simple_reordered
color1 = (130/255, 198/255, 239/255)
color3 = (233/255, 166/255, 58/255)
color2 = (168/255, 44/255, 131/255)



colors = [color1, color2, color3]
# 積み上げ棒グラフを作成
ax = df.plot(kind='bar', stacked=True, figsize=(24, 20), width=0.5, color=colors)

# グラフのタイトルやラベルを設定
#plt.title('Stacked bar chart of segmented', fontsize=18)
#plt.xlabel('Medicines', fontsize=12)
#plt.ylabel('Percentage', fontsize=12)
plt.xticks(fontsize=40)
ax.yaxis.tick_right()

plt.yticks(fontsize=40)
plt.yticks(rotation=90)

# 凡例を'Low', 'Normal', 'High'に設定
ax.legend(['Low', 'Normal', 'High'], loc='upper left', bbox_to_anchor=(1, 1.1), fontsize=12)

# グラフを表示
plt.show()

# %%
a_simple_reordered

# %%
#lym
inj_df = lymphocyte_df
inj_df_2 = lymphocyte_df_2
inj_df_3 = lymphocyte_df_3

inj_df = inj_df.T
inj_df['clu'] = 'Cluster1'
inj_df

inj_df_2 = inj_df_2.T
inj_df_2['clu'] = 'Cluster2'
inj_df_2

inj_df_3 = inj_df_3.T
inj_df_3['clu'] = 'Cluster3'
inj_df_3

inj_df = pd.concat([inj_df, inj_df_2, inj_df_3])


a = inj_df.reset_index()
a.columns # 列 label の取得
a = a.groupby(['index', 'clu']).mean()
new_index = ['Afatinib clu1', 'Afatinib clu2', 'Afatinib clu3', 'All clu1', 'All clu2', 'All clu3', 'Bicalutamide clu1', 'Bicalutamide clu2', 'Bicalutamide clu3', 'Cisplatin clu1', 'Cisplatin clu2', 'Cisplatin clu3', 'Erlotinib clu1', 'Erlotinib clu2', 'Erlotinib clu3', 'Imatinib clu1', 'Imatinib clu2', 'Imatinib clu3', 'Nivolumab clu1', 'Nivolumab clu2', 'Nivolumab clu3', 'Osimertinib clu1', 'Osimertinib clu2', 'Osimertinib clu3', 'Trastuzumab clu1', 'Trastuzumab clu2', 'Trastuzumab clu3']
new_index = ['Afatinib Cluster I    ', 'Afatinib Cluster II   ', 'Afatinib Cluster III  ', 'All Cluster I    ', 'All Cluster II   ', 'All Cluster III  ', 'Bicalutamide Cluster I    ', 'Bicalutamide Cluster II   ', 'Bicalutamide Cluster III  ', 'Cisplatin Cluster I    ', 'Cisplatin Cluster II   ', 'Cisplatin Cluster III  ', 'Erlotinib Cluster I    ', 'Erlotinib Cluster II   ', 'Erlotinib Cluster III  ', 'Imatinib Cluster I    ', 'Imatinib Cluster II   ', 'Imatinib Cluster III  ', 'Nivolumab Cluster I    ', 'Nivolumab Cluster II   ', 'Nivolumab Cluster III  ', 'Osimertinib Cluster I    ', 'Osimertinib Cluster II   ', 'Osimertinib Cluster III  ', 'Trastuzumab Cluster I    ', 'Trastuzumab Cluster II   ', 'Trastuzumab Cluster III  ']

a_simple = a.set_index(pd.Index(new_index))

# 4〜6行目を最後に移動する
new_order = list(a_simple.index[:3]) + list(a_simple.index[6:]) + list(a_simple.index[3:6])
a_simple_reordered = a_simple.reindex(new_order)

a_simple_reordered

df = a_simple_reordered
colors = [color1, color2, color3]
# 積み上げ棒グラフを作成
ax = df.plot(kind='bar', stacked=True, figsize=(24, 20), width=0.5, color=colors)

# グラフのタイトルやラベルを設定
#plt.title('Stacked bar chart of segmented', fontsize=18)
#plt.xlabel('Medicines', fontsize=12)
#plt.ylabel('Percentage', fontsize=12)
plt.xticks(fontsize=40)
ax.yaxis.tick_right()

plt.yticks(fontsize=40)
plt.yticks(rotation=90)

# 凡例を'Low', 'Normal', 'High'に設定
ax.legend(['Low', 'Normal', 'High'], loc='upper left', bbox_to_anchor=(1, 1.1), fontsize=12)

# グラフを表示
plt.show()

# %%
a_simple_reordered

# %%
#HGB
inj_df = hgb_df
inj_df_2 = hgb_df_2
inj_df_3 = hgb_df_3

inj_df = inj_df.T
inj_df['clu'] = 'Cluster1'
inj_df

inj_df_2 = inj_df_2.T
inj_df_2['clu'] = 'Cluster2'
inj_df_2

inj_df_3 = inj_df_3.T
inj_df_3['clu'] = 'Cluster3'
inj_df_3

inj_df = pd.concat([inj_df, inj_df_2, inj_df_3])


a = inj_df.reset_index()
a.columns # 列 label の取得
a = a.groupby(['index', 'clu']).mean()
new_index = ['Afatinib clu1', 'Afatinib clu2', 'Afatinib clu3', 'All clu1', 'All clu2', 'All clu3', 'Bicalutamide clu1', 'Bicalutamide clu2', 'Bicalutamide clu3', 'Cisplatin clu1', 'Cisplatin clu2', 'Cisplatin clu3', 'Erlotinib clu1', 'Erlotinib clu2', 'Erlotinib clu3', 'Imatinib clu1', 'Imatinib clu2', 'Imatinib clu3', 'Nivolumab clu1', 'Nivolumab clu2', 'Nivolumab clu3', 'Osimertinib clu1', 'Osimertinib clu2', 'Osimertinib clu3', 'Trastuzumab clu1', 'Trastuzumab clu2', 'Trastuzumab clu3']
new_index = ['Afatinib Cluster I    ', 'Afatinib Cluster II   ', 'Afatinib Cluster III  ', 'All Cluster I    ', 'All Cluster II   ', 'All Cluster III  ', 'Bicalutamide Cluster I    ', 'Bicalutamide Cluster II   ', 'Bicalutamide Cluster III  ', 'Cisplatin Cluster I    ', 'Cisplatin Cluster II   ', 'Cisplatin Cluster III  ', 'Erlotinib Cluster I    ', 'Erlotinib Cluster II   ', 'Erlotinib Cluster III  ', 'Imatinib Cluster I    ', 'Imatinib Cluster II   ', 'Imatinib Cluster III  ', 'Nivolumab Cluster I    ', 'Nivolumab Cluster II   ', 'Nivolumab Cluster III  ', 'Osimertinib Cluster I    ', 'Osimertinib Cluster II   ', 'Osimertinib Cluster III  ', 'Trastuzumab Cluster I    ', 'Trastuzumab Cluster II   ', 'Trastuzumab Cluster III  ']

a_simple = a.set_index(pd.Index(new_index))

# 4〜6行目を最後に移動する
new_order = list(a_simple.index[:3]) + list(a_simple.index[6:]) + list(a_simple.index[3:6])
a_simple_reordered = a_simple.reindex(new_order)

a_simple_reordered

df = a_simple_reordered
colors = [color1, color2, color3]
# 積み上げ棒グラフを作成
ax = df.plot(kind='bar', stacked=True, figsize=(24, 20), width=0.5, color=colors)

# グラフのタイトルやラベルを設定
#plt.title('Stacked bar chart of segmented', fontsize=18)
#plt.xlabel('Medicines', fontsize=12)
#plt.ylabel('Percentage', fontsize=12)
plt.xticks(fontsize=40)
ax.yaxis.tick_right()

plt.yticks(fontsize=40)
plt.yticks(rotation=90)

# 凡例を'Low', 'Normal', 'High'に設定
ax.legend(['Low', 'Normal', 'High'], loc='upper left', bbox_to_anchor=(1, 1.1), fontsize=12)

# グラフを表示
plt.show()

# %%
a_simple_reordered

# %%
#HCT
inj_df = hct_df
inj_df_2 = hct_df_2
inj_df_3 = hct_df_3

inj_df = inj_df.T
inj_df['clu'] = 'Cluster1'
inj_df

inj_df_2 = inj_df_2.T
inj_df_2['clu'] = 'Cluster2'
inj_df_2

inj_df_3 = inj_df_3.T
inj_df_3['clu'] = 'Cluster3'
inj_df_3

inj_df = pd.concat([inj_df, inj_df_2, inj_df_3])


a = inj_df.reset_index()
a.columns # 列 label の取得
a = a.groupby(['index', 'clu']).mean()
new_index = ['Afatinib clu1', 'Afatinib clu2', 'Afatinib clu3', 'All clu1', 'All clu2', 'All clu3', 'Bicalutamide clu1', 'Bicalutamide clu2', 'Bicalutamide clu3', 'Cisplatin clu1', 'Cisplatin clu2', 'Cisplatin clu3', 'Erlotinib clu1', 'Erlotinib clu2', 'Erlotinib clu3', 'Imatinib clu1', 'Imatinib clu2', 'Imatinib clu3', 'Nivolumab clu1', 'Nivolumab clu2', 'Nivolumab clu3', 'Osimertinib clu1', 'Osimertinib clu2', 'Osimertinib clu3', 'Trastuzumab clu1', 'Trastuzumab clu2', 'Trastuzumab clu3']
new_index = ['Afatinib Cluster I    ', 'Afatinib Cluster II   ', 'Afatinib Cluster III  ', 'All Cluster I    ', 'All Cluster II   ', 'All Cluster III  ', 'Bicalutamide Cluster I    ', 'Bicalutamide Cluster II   ', 'Bicalutamide Cluster III  ', 'Cisplatin Cluster I    ', 'Cisplatin Cluster II   ', 'Cisplatin Cluster III  ', 'Erlotinib Cluster I    ', 'Erlotinib Cluster II   ', 'Erlotinib Cluster III  ', 'Imatinib Cluster I    ', 'Imatinib Cluster II   ', 'Imatinib Cluster III  ', 'Nivolumab Cluster I    ', 'Nivolumab Cluster II   ', 'Nivolumab Cluster III  ', 'Osimertinib Cluster I    ', 'Osimertinib Cluster II   ', 'Osimertinib Cluster III  ', 'Trastuzumab Cluster I    ', 'Trastuzumab Cluster II   ', 'Trastuzumab Cluster III  ']

a_simple = a.set_index(pd.Index(new_index))

# 4〜6行目を最後に移動する
new_order = list(a_simple.index[:3]) + list(a_simple.index[6:]) + list(a_simple.index[3:6])
a_simple_reordered = a_simple.reindex(new_order)

a_simple_reordered
df = a_simple_reordered
colors = [color1, color2, color3]
# 積み上げ棒グラフを作成
ax = df.plot(kind='bar', stacked=True, figsize=(24, 20), width=0.5, color=colors)

# グラフのタイトルやラベルを設定
#plt.title('Stacked bar chart of segmented', fontsize=18)
#plt.xlabel('Medicines', fontsize=12)
#plt.ylabel('Percentage', fontsize=12)
plt.xticks(fontsize=40)
ax.yaxis.tick_right()

plt.yticks(fontsize=40)
plt.yticks(rotation=90)

# 凡例を'Low', 'Normal', 'High'に設定
ax.legend(['Low', 'Normal', 'High'], loc='upper left', bbox_to_anchor=(1, 1.1), fontsize=12)

# グラフを表示
plt.show()

# %%
a_simple_reordered
